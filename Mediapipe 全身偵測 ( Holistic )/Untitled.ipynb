# %%
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

cap = cv2.VideoCapture(0)

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    if not cap.isOpened():
        print("Cannot open camera")
        exit()
    while True:
        ret, img = cap.read()
        if not ret:
            print("Cannot receive frame")
            break
        img = cv2.resize(img,(520,300))
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
        # 面部偵測，繪製臉部網格
        mp_drawing.draw_landmarks(
            img,
            results.face_landmarks,
            mp_holistic.FACEMESH_CONTOURS,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp_drawing_styles
            .get_default_face_mesh_contours_style())
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        cv2.imshow('oxxostudio', img)
        if cv2.waitKey(5) == ord('q'):
            break    # 按下 q 鍵停止
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

# 讀取圖片
img_path = 'twoman0.jpg'  # 請將'your_image_path.jpg'替換為您要處理的圖片路徑
img = cv2.imread(img_path)

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    if img is None:
        print("Cannot read image")
    else:
        img = cv2.resize(img, (520, 300))
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
        # 面部偵測，繪製臉部網格
        mp_drawing.draw_landmarks(
            img,
            results.face_landmarks,
            mp_holistic.FACEMESH_CONTOURS,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp_drawing_styles
            .get_default_face_mesh_contours_style())
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        cv2.imshow('oxxostudio', img)
        cv2.waitKey(0)  # 等待按任意鍵關閉視窗
        cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np
import pyautogui

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

# 設定捕獲區域的座標和大小
screen_region = (0, 0, 1920, 1080)  # 這是捕獲整個螢幕的例子，您可以根據需要調整座標和大小

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    while True:
        # 捕獲螢幕上的畫面
        screen_image = pyautogui.screenshot(region=screen_region)
        img = cv2.cvtColor(np.array(screen_image), cv2.COLOR_RGB2BGR)  # 將 PIL 圖像轉換為 OpenCV 格式

        img = cv2.resize(img, (520, 300))
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
#        # 面部偵測，繪製臉部網格
#        mp_drawing.draw_landmarks(
#            img,
#            results.face_landmarks,
#            mp_holistic.FACEMESH_CONTOURS,
#            landmark_drawing_spec=None,
#            connection_drawing_spec=mp_drawing_styles
#            .get_default_face_mesh_contours_style())
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        cv2.imshow('oxxostudio', img)
        if cv2.waitKey(5) == ord('q'):
            break    # 按下 q 鍵停止

cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np
import pyautogui

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

# 設定捕獲區域的座標和大小
screen_region = (0, 0, 1920, 1080)  # 這是捕獲整個螢幕的例子，您可以根據需要調整座標和大小

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    while True:
        # 捕獲螢幕上的畫面
        screen_image = pyautogui.screenshot(region=screen_region)
        img = cv2.cvtColor(np.array(screen_image), cv2.COLOR_RGB2BGR)  # 將 PIL 圖像轉換為 OpenCV 格式

        img = cv2.resize(img, (520, 300))
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        # 修改鼻子（nose）點的顏色為白色
        if results.pose_landmarks:
            nose_landmark = results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE]
            if nose_landmark.visibility > 0.5:
                nose_x, nose_y = int(nose_landmark.x * img.shape[1]), int(nose_landmark.y * img.shape[0])
                cv2.circle(img, (nose_x, nose_y), 5, (255, 255, 255), -1)

        cv2.imshow('oxxostudio', img)
        if cv2.waitKey(5) == ord('q'):
            break    # 按下 q 鍵停止

cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np
import pyautogui

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

# 設定捕獲區域的座標和大小
screen_region = (0, 0, 1920, 1080)  # 這是捕獲整個螢幕的例子，您可以根據需要調整座標和大小

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    while True:
        # 捕獲螢幕上的畫面
        screen_image = pyautogui.screenshot(region=screen_region)
        img = cv2.cvtColor(np.array(screen_image), cv2.COLOR_RGB2BGR)  # 將 PIL 圖像轉換為 OpenCV 格式

        img = cv2.resize(img, (520, 300))
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        # 修改鼻子（nose）點的顏色為白色
        if results.pose_landmarks:
            nose_landmark = results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE]
            if nose_landmark.visibility > 0.5:
                nose_x, nose_y = int(nose_landmark.x * img.shape[1]), int(nose_landmark.y * img.shape[0])
                cv2.circle(img, (nose_x, nose_y), 5, (255, 255, 255), -1)
                # 移動鼠標到鼻子位置
                pyautogui.moveTo(nose_x, nose_y)

        cv2.imshow('oxxostudio', img)
        if cv2.waitKey(5) == ord('q'):
            break    # 按下 q 鍵停止

cv2.destroyAllWindows()

# %% [markdown]
# nose
#
# mouth_right
#
# mouth_left
#
# right_ear
#
# left_ear
#
# right_eye_outer
#
# left_eye_inner
#
# right eye_inner
#
# left_eye_outer
#
# left_eye
#
# right_eye

# %%
import cv2
import mediapipe as mp
import numpy as np
import pyautogui

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

# 設定捕獲區域的座標和大小
screen_region = (0, 0, 1920, 1080)  # 這是捕獲整個螢幕的例子，您可以根據需要調整座標和大小

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    while True:
        # 捕獲螢幕上的畫面
        screen_image = pyautogui.screenshot(region=screen_region)
        img = cv2.cvtColor(np.array(screen_image), cv2.COLOR_RGB2BGR)  # 將 PIL 圖像轉換為 OpenCV 格式

        img = cv2.resize(img, (480, 270))
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        # 修改鼻子（nose）點的顏色為白色
        if results.pose_landmarks:
            nose_landmark = results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE]
            if nose_landmark.visibility > 0.5:
                nose_x, nose_y = int(nose_landmark.x * img.shape[1]), int(nose_landmark.y * img.shape[0])
                cv2.circle(img, (nose_x, nose_y), 5, (255, 255, 255), -1)

                # 顯示鼻子座標
                cv2.putText(img, f"Nose: ({nose_x}, {nose_y})", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        cv2.imshow('oxxostudio', img)
        if cv2.waitKey(5) == ord('q'):
            break    # 按下 q 鍵停止

cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np
import pyautogui
import keyboard  # 需要安裝 keyboard 模組

mp_drawing = mp.solutions.drawing_utils         # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles # mediapipe 繪圖樣式
mp_holistic = mp.solutions.holistic             # mediapipe 全身偵測方法

# 設定捕獲區域的座標和大小
screen_region = (0, 0, 1920, 1080)  # 這是捕獲整個螢幕的例子，您可以根據需要調整座標和大小

# mediapipe 啟用偵測全身
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:

    while True:
        # 捕獲螢幕上的畫面
        screen_image = pyautogui.screenshot(region=screen_region)
        img = cv2.cvtColor(np.array(screen_image), cv2.COLOR_RGB2BGR)  # 將 PIL 圖像轉換為 OpenCV 格式

        img = cv2.resize(img, (480, 270))  # 調整畫面尺寸
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # 將 BGR 轉換成 RGB
        results = holistic.process(img2)              # 開始偵測全身
        # 身體偵測，繪製身體骨架
        mp_drawing.draw_landmarks(
            img,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_pose_landmarks_style())

        # 修改鼻子（nose）點的顏色為白色
        if results.pose_landmarks:
            nose_landmark = results.pose_landmarks.landmark[mp_holistic.PoseLandmark.NOSE]
            if nose_landmark.visibility > 0.5:
                nose_x, nose_y = int(nose_landmark.x * img.shape[1]), int(nose_landmark.y * img.shape[0])
                cv2.circle(img, (nose_x, nose_y), 5, (255, 255, 255), -1)

                # 顯示鼻子座標
                cv2.putText(img, f"Nose: ({nose_x}, {nose_y})", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

                # 檢查是否沒有按住 Caps Lock 鍵，如果是，則移動滑鼠到新座標（需要將座標乘以4）
                if not keyboard.is_pressed('Caps Lock'):
                    new_x, new_y = nose_x * 4, nose_y * 4
                    pyautogui.moveTo(new_x, new_y)

        cv2.imshow('oxxostudio', img)
        if cv2.waitKey(5) == ord('q'):
            break    # 按下 q 鍵停止

cv2.destroyAllWindows()

# %%
pip install keyboard
# Out:
# ...
#      ---------------------------------------- 0.0/58.1 kB ? eta -:--:--
#      ---------------------------------------- 58.1/58.1 kB 3.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
